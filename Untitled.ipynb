# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('41477_2022_1339_MOESM2_ESM.xlsx', sheet_name='Present-day olive-growing areas')

# %%
df
# Out:
#     Dataset - Present-day olive-growing areas Unnamed: 1         Unnamed: 2  \
# 0                                         NaN        NaN                NaN
# 1                                         NaN        NaN  Temperatures (°C)
# 2                                   Longitude   Latitude            January
# 3                                       -9.25      39.25               11.6
# 4                                       -8.75      37.25               12.3
# ..                                        ...        ...                ...
# 323                                     37.25      36.25                6.8
# 324                                     37.25      36.75                6.1
# 325                                     37.75      36.75                6.1
# 326                                     38.25      36.75                6.4
# 327                                     38.75      36.75                6.7
#
# ...
